# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

Char_name = "Roblox"

data_points = np.load(f"./Dataset/{Char_name}.npy")[0].reshape(-1, 3)
weights = np.load(f"./Dataset/{Char_name}_weight.npy")


plt.scatter(data_points.T[0],data_points.T[1], c=weights)
plt.title(Char_name)
plt.colorbar()
